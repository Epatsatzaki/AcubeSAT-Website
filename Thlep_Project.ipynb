# %% [markdown]
# <a href="https://colab.research.google.com/github/Epatsatzaki/AcubeSAT-Website/blob/main/Thlep_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/MyDrive/Thlep_Project/Images.zip" -d "/content/datasets"
